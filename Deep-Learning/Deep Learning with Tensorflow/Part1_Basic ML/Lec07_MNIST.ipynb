# %% [markdown]
# # MNIST Introduction
# - MNIST(Modified National Institute of Standards and Technology database)는 0~9까지의 손으로 쓴 숫자들로 이루어진 대형 데이터베이스

# %%
import numpy as np
import tensorflow as tf

tf.random.set_seed(777) # for reproducibility
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# # Data

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 정규화
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# # Classification Model
# - TensorFlow Keras API를 통해 모델 정의

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.2176 - accuracy: 0.9352
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0966 - accuracy: 0.9705
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0669 - accuracy: 0.9791
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0542 - accuracy: 0.9828
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0445 - accuracy: 0.9861

# %% [markdown]
# # Model Evaluation

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0703 - accuracy: 0.9797
# [0.07025158405303955, 0.9797000288963318]
